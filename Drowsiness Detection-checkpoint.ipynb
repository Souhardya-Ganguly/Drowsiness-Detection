# %% [markdown]
# # 1. Installing and importing dependencies

# %%
#!pip install torch==1.8.2 torchvision==0.9.2 torchaudio===0.8.2 --extra-index-url https://download.pytorch.org/whl/lts/1.8/cu111

# %%
#!git clone https://github.com/ultralytics/yolov5

# %%
cd yolov5
# Out:
# C:\Users\ASUS\Desktop\Drowsiness Detection\yolov5

# %%
#pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
#Getting the baseline pre trained model hosted in pytorchub
#yolov5s because we have gotten the small model hosted that has been trained on the coco dataset
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\ASUS/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-9-18 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# # 3. Make Detections with images

# %%
img = 'https://scontent.fccu3-1.fna.fbcdn.net/v/t1.6435-9/87050017_2593241850803166_7896076075506073600_n.jpg?_nc_cat=108&ccb=1-7&_nc_sid=730e14&_nc_ohc=H3tccKhI96AAX_qZ6ln&_nc_ht=scontent.fccu3-1.fna&oh=00_AT-iib9F8tr6d1-KTLqbHc-ryzluwnl6v69Kxbo1ooaI0w&oe=634D59F3'

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
results = model(img)
results.print()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\anaconda3\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~\anaconda3\lib\socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# ...

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()

# %% [markdown]
# # Real Time Detection

# %%
# cap = cv2.VideoCapture(0)
# while cap.isOpened():
#     ret, frame = cap.read()
    
#     # Make detections 
#     results = model(frame)
    
#     cv2.imshow('YOLO', np.squeeze(results.render()))
#     #On pressing q, we exit from the window
#     if cv2.waitKey(10) & 0xFF == ord('q'):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# # Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
cd ..
# Out:
# C:\Users\ASUS\Desktop\Drowsiness Detection

# %%
#Creates data/images

try:
  os.makedirs('data/images')
except FileExistsError:
  print("Directory exists!!")
except:
  print("Something else went wrong")
# Out:
# Directory exists!!

# %%
#cd yolov5

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 20

# %%
# cap = cv2.VideoCapture(0)
# # Loop through labels
# for label in labels:
#     print('Collecting images for {}'.format(label))
#     time.sleep(5)
    
#     # Loop through image range
#     for img_num in range(number_imgs):
#         print('Collecting images for {}, image number {}'.format(label, img_num))
        
#         # Webcam feed
#         ret, frame = cap.read()
        
#         # Naming out image path
#         imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
#         # Writes out image to file 
#         cv2.imwrite(imgname, frame)
        
#         # Render to the screen
#         cv2.imshow('Image Collection', frame)
        
#         # 2 second delay between captures
#         time.sleep(2)
        
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
# cap.release()
# cv2.destroyAllWindows()

# %%
for label in labels:
    print('Images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Image number {} for {} label is called:'.format(img_num,label))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# Images for awake
# Image number 0 for awake label is called:
# data\images\awake.215c14e0-3831-11ed-8fdc-b48c9d36973c.jpg
# Image number 1 for awake label is called:
# data\images\awake.215c14e1-3831-11ed-8b75-b48c9d36973c.jpg
# Image number 2 for awake label is called:
# data\images\awake.215c14e2-3831-11ed-bbf7-b48c9d36973c.jpg
# Image number 3 for awake label is called:
# data\images\awake.215c14e3-3831-11ed-b897-b48c9d36973c.jpg
# Image number 4 for awake label is called:
# data\images\awake.215c14e4-3831-11ed-a220-b48c9d36973c.jpg
# Image number 5 for awake label is called:
# data\images\awake.215c14e5-3831-11ed-9bf1-b48c9d36973c.jpg
# Image number 6 for awake label is called:
# data\images\awake.215c14e6-3831-11ed-bce7-b48c9d36973c.jpg
# Image number 7 for awake label is called:
# data\images\awake.215c14e7-3831-11ed-8fae-b48c9d36973c.jpg
# Image number 8 for awake label is called:
# data\images\awake.215c14e8-3831-11ed-b705-b48c9d36973c.jpg
# ...

# %%
#!git clone https://github.com/tzutalin/labelImg

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
#Creates data/labels

try:
  os.makedirs('data/labels')
except FileExistsError:
  print("Directory exists!!")
except:
  print("Something else went wrong")
# Out:
# Directory exists!!

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yaml --weights yolov5s.pt --cache ram --workers 2
# Out:
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=5, batch_size=2, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# fatal: cannot change to 'C:\Users\ASUS\Desktop\Drowsiness': No such file or directory
# YOLOv5  2022-9-19 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# ...

# %% [markdown]
# # Load Custom Model

# %%
#exp9 for close range
#exp12 for distance
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp12/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\ASUS/.cache\torch\hub\master.zip
# YOLOv5  2022-9-19 Python-3.9.12 torch-1.8.2+cu111 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
